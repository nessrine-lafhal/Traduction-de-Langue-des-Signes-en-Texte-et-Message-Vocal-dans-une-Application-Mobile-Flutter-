# %%
import cv2           
import numpy as np   
import os            
from matplotlib import pyplot as plt



         
import mediapipe as mp  #pour la detection de corps
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical  




# Initialiser MediaPipe Holistic, qui est une solution pour la détection du corps entier
mp_holistic = mp.solutions.holistic 

# Initialiser MediaPipe Drawing Utils, qui contient des utilitaires pour dessiner les annotations
mp_drawing = mp.solutions.drawing_utils




def mediapipe_detection(image, model):
    # Convertir l'image de BGR en RGB
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    
    # Rendre l'image non modifiable (non writeable)
    image.flags.writeable = False                  # Image is no longer writeable
    
    # Faire la prédiction en utilisant le modèle MediaPipe
    results = model.process(image)                 # Make prediction
    
    # Rendre l'image modifiable à nouveau
    image.flags.writeable = True                   # Image is now writeable
    
    # Convertir l'image de RGB en BGR
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR CONVERSION RGB 2 BGR
    
    # Retourner l'image et les résultats de la prédiction
    return image, results




def draw_landmarks(image, results):
    # Dessiner les connexions du visage
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    
    # Dessiner les connexions de la pose (corps)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    
    # Dessiner les connexions de la main gauche
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    
    # Dessiner les connexions de la main droite
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

    
# draw_landmarks -> Function does not return the image but rather applies the landmark visualizations to the current image in place    



def draw_styled_landmarks(image, results):
    # Dessiner les connexions du visage
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             # Spécifications pour colorer les points de repère (points) du visage
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             # Spécifications pour colorer les connexions (lignes) du visage
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Dessiner les connexions de la pose (corps)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             # Spécifications pour colorer les points de repère (points) du corps
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             # Spécifications pour colorer les connexions (lignes) du corps
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Dessiner les connexions de la main gauche
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             # Spécifications pour colorer les points de repère (points) de la main gauche
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             # Spécifications pour colorer les connexions (lignes) de la main gauche
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Dessiner les connexions de la main droite  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             # Spécifications pour colorer les points de repère (points) de la main droite
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             # Spécifications pour colorer les connexions (lignes) de la main droite
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             ) 

    
#we are just formatting or updating our draw landmark function(that's not complusory though, u can use only standard drwa_landmark func)    
    



import cv2
import mediapipe as mp

# Initialiser la capture vidéo à partir de la webcam
cap = cv2.VideoCapture(0)

# Définir le modèle MediaPipe Holistic avec des seuils de détection et de suivi
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # Lire le flux vidéo
        ret, frame = cap.read()
        
        if not ret:
            continue
        
        # Faire les détections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Dessiner les points de repère
        draw_styled_landmarks(image, results)  # Utiliser la fonction améliorée pour dessiner les points de repère avec des couleurs différentes
        
        # Afficher à l'écran
        cv2.imshow('OpenCV Feed', image)

        # Quitter proprement
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Libérer la capture vidéo et fermer les fenêtres
cap.release()
cv2.destroyAllWindows()


# Compter le nombre de points de repère détectés sur la pose (corps)
num_pose_landmarks = len(results.pose_landmarks.landmark) 


results


# Appeler la fonction pour dessiner les points de repère sur le visage, le corps, et les mains
draw_landmarks(frame, results)




pose = []               
# Pour chaque point de repère de la pose détecté, crée un tableau numpy avec les coordonnées x, y, z et la visibilité, puis ajoute-le à la liste 'pose'.
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)




# Crée un tableau numpy plat avec les coordonnées x, y, z et la visibilité des points de repère de la pose; sinon, initialise un tableau de zéros de taille 132 si aucun point de repère n'est détecté.
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)

# Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère du visage; sinon, initialise un tableau de zéros de taille 1404 si aucun point de repère n'est détecté.
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère de la main gauche; sinon, initialise un tableau de zéros de taille 63 si aucun point de repère n'est détecté.
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)

# Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère de la main droite; sinon, initialise un tableau de zéros de taille 63 si aucun point de repère n'est détecté.
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)



def extract_keypoints(results):
    # Crée un tableau numpy plat avec les coordonnées x, y, z et la visibilité des points de repère de la pose; sinon, initialise un tableau de zéros de taille 132 si aucun point de repère n'est détecté.
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    
    # Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère du visage; sinon, initialise un tableau de zéros de taille 1404 si aucun point de repère n'est détecté.
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    
    # Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère de la main gauche; sinon, initialise un tableau de zéros de taille 63 si aucun point de repère n'est détecté.
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    
    # Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère de la main droite; sinon, initialise un tableau de zéros de taille 63 si aucun point de repère n'est détecté.
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
    # Concatène tous les tableaux de points de repère (pose, visage, main gauche, main droite) en un seul tableau numpy.
    return np.concatenate([pose, face, lh, rh])



result_test = extract_keypoints(results)



np.save('0', result_test)   
# en enregistrant chaque image sous forme de tableau numpy à l'intérieur de notre dossier 'MP_Data', nous aurons donc 30 tableaux numpy dans chaque dossier d'actions


np.load('0.npy')

# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect, including Tunisian Sign Language actions in French (transliterated)
# Actions that we try to detect, including Tunisian Sign Language actions in French (transliterated)
actions = np.array([ 'n3ass','lunettes','je froid','3aslama', 'Chokran', 'Nhebbek', 'La',  'j aime', 'j aime pas', 'Nakel', 'Nchrob' ,  'Bahi',
      'Telephone',   's il te plait', 'pleur','fort', 'lissar','Waqtach',
    'Limine' , 'sghir', 'kbir', 'stop', 'sma3ni','fakar','chof'])





#Trente vidéos de données
no_sequences = 30

# Les vidéos dureront 30 images
sequence_length = 30


# Vérifie si le chemin de répertoire spécifié par DATA_PATH n'existe pas.
# Si le répertoire n'existe pas, il le crée.
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)



# Itère sur chaque action dans la liste d'actions
for action in actions: 
    # Pour chaque action, itère sur le nombre de séquences
    for sequence in range(no_sequences):
        try:
            # Essaye de créer un répertoire pour l'action et la séquence spécifiée dans DATA_PATH
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            # Ignore les erreurs (par exemple, si le répertoire existe déjà) et continue
            pass



label_map = {label:num for num, label in enumerate(actions)}




# Initialise deux listes vides pour stocker les séquences et les étiquettes
sequences, labels = [], []

# Itère à travers chaque action dans la liste d'actions
for action in actions:
    # Pour chaque action, itère à travers chaque séquence (vidéo)
    for sequence in range(no_sequences):
        # Crée une liste pour stocker les frames de la séquence actuelle
        window = []
        # Itère à travers chaque frame de la séquence
        for frame_num in range(sequence_length):
            # Charge les points de repère extraits (au format .npy) pour la frame courante
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            # Ajoute les points de repère à la fenêtre (séquence)
            window.append(res)
        # Ajoute la fenêtre (séquence complète) à la liste des séquences
        sequences.append(window)
        # Ajoute l'étiquette correspondant à l'action à la liste des étiquettes
        labels.append(label_map[action])


X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
# Out:
# c:\Users\Nessrine\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D
from tensorflow.keras.optimizers import Adam

# Définir le modèle
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(30, 1662)))  # Assurez-vous que cette forme est correcte
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(len(actions), activation='softmax'))
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])


# Entraîner le modèle
history = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test))

# Évaluer le modèle
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")

from tensorflow.keras.models import save_model

# Sauvegarder le modèle dans un fichier .h5
model.save('(CNN+LSTM)2.h5')
# Out:
# c:\Users\Nessrine\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 102ms/step - accuracy: 0.0524 - loss: 3.2328 - val_accuracy: 0.1316 - val_loss: 3.1572
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.0850 - loss: 3.1058 - val_accuracy: 0.1316 - val_loss: 3.0146
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1160 - loss: 2.9605 - val_accuracy: 0.1316 - val_loss: 2.8748
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1732 - loss: 2.7454 - val_accuracy: 0.0789 - val_loss: 2.7936
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1359 - loss: 2.7013 - val_accuracy: 0.1053 - val_loss: 2.6790
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8685 - loss: 0.4223 - val_accuracy: 0.9737 - val_loss: 0.2096
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9100 - loss: 0.3098 - val_accuracy: 0.9474 - val_loss: 0.2450
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9261 - loss: 0.2624 - val_accuracy: 0.8684 - val_loss: 0.3188
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9084 - loss: 0.2808 - val_accuracy: 0.9211 - val_loss: 0.3327
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9302 - loss: 0.2462 - val_accuracy: 0.9737 - val_loss: 0.2797
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8881 - loss: 0.3782 - val_accuracy: 0.9737 - val_loss: 0.1371
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9134 - loss: 0.2891 - val_accuracy: 0.8947 - val_loss: 0.3361
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8311 - loss: 0.6387 - val_accuracy: 0.8684 - val_loss: 0.5219
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8896 - loss: 0.3619 - val_accuracy: 0.8684 - val_loss: 0.2847
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9198 - loss: 0.2878 - val_accuracy: 0.9737 - val_loss: 0.1814
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8891 - loss: 0.3759 - val_accuracy: 0.9474 - val_loss: 0.2697
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8909 - loss: 0.3592 - val_accuracy: 0.8947 - val_loss: 0.4232
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8714 - loss: 0.3954 - val_accuracy: 0.7895 - val_loss: 0.4647
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9175 - loss: 0.2658 - val_accuracy: 0.8947 - val_loss: 0.4434
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8999 - loss: 0.3064 - val_accuracy: 0.9474 - val_loss: 0.2862
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9441 - loss: 0.2957
# Test Accuracy: 0.95
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import cv2
import numpy as np
import mediapipe as mp
from tensorflow.keras.models import load_model
import tensorflow as tf

# Initialiser MediaPipe Holistic, qui est une solution pour la détection du corps entier
mp_holistic = mp.solutions.holistic 

# Initialiser MediaPipe Drawing Utils, qui contient des utilitaires pour dessiner les annotations
mp_drawing = mp.solutions.drawing_utils

def mediapipe_detection(image, model):
    # Convertir l'image de BGR en RGB
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    
    # Rendre l'image non modifiable (non writeable)
    image.flags.writeable = False                  # Image is no longer writeable
    
    # Faire la prédiction en utilisant le modèle MediaPipe
    results = model.process(image)                 # Make prediction
    
    # Rendre l'image modifiable à nouveau
    image.flags.writeable = True                   # Image is now writeable
    
    # Convertir l'image de RGB en BGR
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR CONVERSION RGB 2 BGR
    
    # Retourner l'image et les résultats de la prédiction
    return image, results

def draw_landmarks(image, results):
    # Dessiner les connexions du visage
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    
    # Dessiner les connexions de la pose (corps)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    
    # Dessiner les connexions de la main gauche
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    
    # Dessiner les connexions de la main droite
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections



def draw_styled_landmarks(image, results):
    # Dessiner les connexions du visage
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             # Spécifications pour colorer les points de repère (points) du visage
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             # Spécifications pour colorer les connexions (lignes) du visage
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Dessiner les connexions de la pose (corps)
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             # Spécifications pour colorer les points de repère (points) du corps
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             # Spécifications pour colorer les connexions (lignes) du corps
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Dessiner les connexions de la main gauche
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             # Spécifications pour colorer les points de repère (points) de la main gauche
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             # Spécifications pour colorer les connexions (lignes) de la main gauche
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Dessiner les connexions de la main droite  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             # Spécifications pour colorer les points de repère (points) de la main droite
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             # Spécifications pour colorer les connexions (lignes) de la main droite
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))
    

def extract_keypoints(results):
    # Crée un tableau numpy plat avec les coordonnées x, y, z et la visibilité des points de repère de la pose; sinon, initialise un tableau de zéros de taille 132 si aucun point de repère n'est détecté.
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    
    # Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère du visage; sinon, initialise un tableau de zéros de taille 1404 si aucun point de repère n'est détecté.
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    
    # Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère de la main gauche; sinon, initialise un tableau de zéros de taille 63 si aucun point de repère n'est détecté.
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    
    # Crée un tableau numpy plat avec les coordonnées x, y, z des points de repère de la main droite; sinon, initialise un tableau de zéros de taille 63 si aucun point de repère n'est détecté.
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
    # Concatène tous les tableaux de points de repère (pose, visage, main gauche, main droite) en un seul tableau numpy.
    return np.concatenate([pose, face, lh, rh])
    
actions = np.array([ 'n3ass','lunettes','je froid','3aslama', 'Chokran', 'Nhebbek', 'La',  'j aime', 'j aime pas', 'Nakel', 'Nchrob' ,  'Bahi',
      'Telephone',   's il te plait', 'pleur','fort', 'lissar','Waqtach',
    'Limine' , 'sghir', 'kbir', 'stop', 'sma3ni','fakar','chof'])


# Charger le modèle pré-entraîné
model = tf.keras.models.load_model(r'C:\Users\Nessrine\StudioProjects\flask-app\(CNN+LSTM)2.h5')

# Définir les couleurs pour les actions
colors = [(245,117,16), (117,245,16), (16,117,245)] * (len(actions) // 3 + 1)
colors = colors[:len(actions)]  # S'assurer que colors a la même longueur que actions

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        if num >= len(actions):  # Vérifier que l'indice est dans les limites
            break
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    return output_frame

# Variables pour la détection des gestes
sequence = []            # Liste pour stocker les séquences de points clés
sentence = []            # Liste pour stocker les actions détectées successivement
predictions = []        # Liste pour stocker les prédictions du modèle
threshold = 0.8          # Seuil de confiance pour valider une prédiction

# Ouvrir la capture vidéo à partir de la webcam
cap = cv2.VideoCapture(0)

# Initialiser le modèle Mediapipe pour la détection des gestes
with mp.solutions.holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # Lire une image du flux vidéo
        ret, frame = cap.read()

        # Effectuer des détections sur l'image
        image, results = mediapipe_detection(frame, holistic)
        
        # Dessiner les repères sur l'image
        draw_styled_landmarks(image, results)
        
        # Logique de prédiction
        keypoints = extract_keypoints(results)  # Extraire les points clés de l'image
        sequence.append(keypoints)             # Ajouter les points clés à la séquence
        sequence = sequence[-20:]              # Conserver seulement les 20 derniers frames
        
        if len(sequence) == 20:                # Si la séquence contient 20 frames
            sequence_np = np.array(sequence, dtype=np.float32)  # Convertir en numpy array avec type float32
            res = model.predict(np.expand_dims(sequence_np, axis=0))[0]  # Prédire l'action à partir de la séquence
            print(actions[np.argmax(res)])    # Afficher l'action prédite
            predictions.append(np.argmax(res))  # Ajouter la prédiction à la liste des prédictions
            
            # Logique de visualisation
            if np.unique(predictions[-10:])[0] == np.argmax(res):  # Si la prédiction dominante sur les 10 derniers frames est constante
                if res[np.argmax(res)] > threshold:  # Vérifier si la probabilité est au-dessus du seuil
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:  # Ajouter l'action à la sentence si elle est différente de la précédente
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])  # Ajouter la première action détectée à la sentence

            if len(sentence) > 5:  # Limiter la taille de la sentence à 5 actions
                sentence = sentence[-5:]

            # Visualiser les probabilités de chaque action
            image = prob_viz(res, actions, image, colors)
        
        # Dessiner un fond coloré et ajouter le texte de la sentence sur l'image
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,40), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Afficher l'image avec les visualisations
        cv2.imshow('OpenCV Feed', image)

        # Quitter la boucle lorsque la touche 'q' est pressée
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Libérer la capture vidéo et fermer toutes les fenêtres ouvertes
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# pleur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# lunettes
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# kbir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fort
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# n3ass
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Telephone
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nchrob
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# La
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# sma3ni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# sma3ni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# sma3ni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# sma3ni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# sma3ni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# sma3ni
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# chof
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# fakar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# chof
# ...
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Waqtach
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# je froid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nakel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# j aime pas
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Nhebbek
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Chokran
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# s il te plait
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# sghir
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Bahi
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 3aslama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 3aslama
